# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

# %%
articles = pd.read_csv("/Users/sidgraph/Desktop/LLM_KG_RecSys/graph_rec/data/filtered_articles.csv")
customers = pd.read_csv("/Users/sidgraph/Desktop/LLM_KG_RecSys/graph_rec/data/filtered_customers.csv")
transactions = pd.read_csv("/Users/sidgraph/Desktop/LLM_KG_RecSys/graph_rec/data/filtered_transactions_train.csv")

# %%
articles.head()
# Out:
#    article_id  product_code                  prod_name  product_type_no  \
# 0   108775015        108775                  Strap top              253
# 1   108775044        108775                  Strap top              253
# 2   110065001        110065          OP T-shirt (Idro)              306
# 3   111565001        111565        20 den 1p Stockings              304
# 4   111586001        111586  Shape Up 30 den 1p Tights              273
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2               Bra           Underwear                  1010016
# 3  Underwear Tights      Socks & Tights                  1010016
# 4   Leggings/Tights  Garment Lower body                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# ...

# %%
customers.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  000383021a8cf9a542b9c855b42f99aa76374873661e83...  NaN     NaN
# 1  007fc3638a2b9362c21bd53744fb08168939012636db52...  1.0     1.0
# 2  012cc72686e288fc6a1ce03361c5e2cedaf1b38a4a9294...  1.0     1.0
# 3  01837c5643f9afc91cde10997749a9df75275b4d0ca965...  1.0     1.0
# 4  01e2cc6a88561c7765fdef3c0fae547791d6db3d737824...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  30.0
# 1             ACTIVE              Regularly  21.0
# 2             ACTIVE              Regularly  26.0
# 3             ACTIVE              Regularly  29.0
# 4             ACTIVE              Regularly  49.0
#
#                                          postal_code
# 0  110c914bcac2c21cff810ea4be5bb91580ce3c8ffa431e...
# 1  44148e1f5f23d3dd6a8155334450d406ad0f18e3aeb886...
# 2  2c29ae653a9282cce4151bd87643c907644e09541abc28...
# ...

# %%
transactions.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  0e4d986c7b54788b33e9f5959f240bc86d5a9bf4bf087d...   448509017
# 1  2018-09-20  0e4d986c7b54788b33e9f5959f240bc86d5a9bf4bf087d...   448509017
# 2  2018-09-20  61011e3b42e62b2359551663487abad28a7b1113c41d87...   564786001
# 3  2018-09-20  61011e3b42e62b2359551663487abad28a7b1113c41d87...   634009004
# 4  2018-09-20  61011e3b42e62b2359551663487abad28a7b1113c41d87...   708021001
#
#       price  sales_channel_id
# 0  0.042356                 2
# 1  0.042356                 2
# 2  0.022017                 2
# 3  0.025407                 2
# 4  0.016932                 2
